# %% [markdown]
# <a href="https://colab.research.google.com/github/kavyasree2615/Nasscom15/blob/main/python_pandas_lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python Pandas — Fundamentals Lab
#
# Based on the **"Python pandas"** slide deck (Series, DataFrame, and Panel basics).
#
# **Style:** each topic has a worked **DEMO** (taken from the slides) followed by a 🧪 **LAB EXERCISE** where you replace `# YOUR CODE HERE` with working code.
#
# Run cells top to bottom with **Shift + Enter**.

# %%
import pandas as pd
import numpy as np

print('Setup complete. Pandas', pd.__version__)

# %% [markdown]
# ## 1. What is pandas?

# %% [markdown]
# pandas is a Python package that provides fast, flexible, and expressive data structures for working with 'relational' or 'labeled' data. It is built on top of NumPy, was developed by **Wes McKinney in 2008**, and the name comes from **"Panel Data"**.
#
# It provides **three** core data structures:
#
# | Data Structure | Dimensions | Description |
# |---|---|---|
# | **Series** | 1 | 1D labeled, homogeneous array, size-immutable |
# | **DataFrame** | 2 | 2D labeled, size-mutable, heterogeneously-typed columns |
# | **Panel** | 3 | 3D labeled, size-mutable (legacy — rarely used today) |

# %% [markdown]
# #### 🧪 LAB EXERCISE 1 — Setup check
# 1. Print the installed pandas version using `pd.__version__`.
# 2. Print the installed NumPy version using `np.__version__`.

# %%
# YOUR CODE HERE
import pandas as pd
import numpy as np
print('Pandas version:', pd.__version__)

# YOUR CODE HERE
print('NumPy version:', np.__version__)
# Out:
# Pandas version: 2.2.2
# NumPy version: 2.0.2

# %% [markdown]
# ## 2. Creating a Series

# %%
# -----------------------------------------------------------
# 🔹 2A. DEMO — Empty Series
# -----------------------------------------------------------

s = pd.Series(dtype='float64')
print(s)
# Out:
# Series([], dtype: float64)

# %%
# -----------------------------------------------------------
# 🔹 2B. DEMO — Series from an ndarray (default integer index)
# -----------------------------------------------------------
info = np.array(['P', 'a', 'n', 'd', 'a', 's'])
s = pd.Series(info)
print(s)
# Out:
# 0    P
# 1    a
# 2    n
# 3    d
# 4    a
# 5    s
# dtype: object

# %%
# -----------------------------------------------------------
# 🔹 2C. DEMO — Series from a dict (keys become the index)
# -----------------------------------------------------------
data = {'a': 0., 'b': 1., 'c': 2.}
s = pd.Series(data)
print(s)
# Out:
# a    0.0
# b    1.0
# c    2.0
# dtype: float64

# %%
# -----------------------------------------------------------
# 🔹 2D. DEMO — Series from a scalar (value repeated to match index)
# -----------------------------------------------------------
s = pd.Series(5, index=[0, 1, 2, 3])
print(s)
# Out:
# 0    5
# 1    5
# 2    5
# 3    5
# dtype: int64

# %% [markdown]
# #### 🧪 LAB EXERCISE 2 — Build Series three ways
# 1. Create a Series called `s_array` from the numpy array `np.array(['x', 'y', 'z'])` (default index).
# 2. Create a Series called `s_dict` from the dict `{'math': 90, 'sci': 85, 'eng': 78}`.
# 3. Create a Series called `s_scalar` where the value `7` is repeated across index labels `['q1', 'q2', 'q3', 'q4']`.

# %%
# 1. Series from array
# YOUR CODE HERE
S=np.array(['x','y','z'])
s_array = pd.Series(S)
print(s_array)

# 2. Series from dict
# YOUR CODE HERE
P={'math':90, 'sci':85, 'eng':78}
s_dict = pd.Series(P)
print(s_dict)

# 3. Series from scalar
# YOUR CODE HERE
import numpy as np
s_scalar = pd.Series(7, index=['q1:', 'q2:', 'q3:' ,'q4:'])
print(s_scalar)
# Out:
# 0    x
# 1    y
# 2    z
# dtype: object
# math    90
# sci     85
# eng     78
# dtype: int64
# q1:    7
# q2:    7
# q3:    7
# q4:    7
# dtype: int64

# %% [markdown]
# ## 3. Accessing Data in a Series

# %%
# -----------------------------------------------------------
# 🔹 3A. DEMO — access by position and by label
# -----------------------------------------------------------
s = pd.Series([1, 2, 3, 4, 5], index=['a', 'b', 'c', 'd', 'e'])

print('First element (position 0):', s.iloc[0])
print('First three elements:')
print(s.iloc[:3])

print('\nElement at label "a":', s.loc['a'])
print('Elements at labels a, c, d:')
print(s.loc[['a', 'c', 'd']])
# Out:
# First element (position 0): 1
# First three elements:
# a    1
# b    2
# c    3
# dtype: int64
#
# Element at label "a": 1
# Elements at labels a, c, d:
# a    1
# c    3
# d    4
# dtype: int64

# %% [markdown]
# #### 🧪 LAB EXERCISE 3 — Slicing and labels
# Using `s = pd.Series([10, 20, 30, 40, 50], index=['v', 'w', 'x', 'y', 'z'])`:
# 1. Print the last element by position (hint: `.iloc[-1]`).
# 2. Print the elements labeled `'w'` and `'y'` together.
# 3. Print the first 2 elements using label-based slicing (hint: `.loc['v':'w']`).

# %%
s = pd.Series([10, 20, 30, 40, 50], index=['v', 'w', 'x', 'y', 'z'])

# 1. Last element by position
# YOUR CODE HERE
print('Last element:', s.iloc[-1])

# 2. Elements at 'w' and 'y'
# YOUR CODE HERE
print("elements at label w,y:")
print(s.loc[['w','y']])

# 3. Label-based slice 'v' to 'w'
# YOUR CODE HERE
print('first 2 elemets:' ,s.loc['v':'w'])
# Out:
# Last element: 50
# elements at label w,y:
# w    20
# y    40
# dtype: int64
# first 2 elemets: v    10
# w    20
# dtype: int64

# %% [markdown]
# ## 4. Creating a DataFrame

# %%
# -----------------------------------------------------------
# 🔹 4A. DEMO — DataFrame from a list of lists
# -----------------------------------------------------------
import pandas as pd
data = [['Alex', 10], ['Bob', 12], ['Clarke', 13]]
df = pd.DataFrame(data, columns=['Name', 'Age'])
print(df)
# Out:
#      Name  Age
# 0    Alex   10
# 1     Bob   12
# 2  Clarke   13

# %%
# -----------------------------------------------------------
# 🔹 4B. DEMO — DataFrame from a dict of lists
# -----------------------------------------------------------
data = {'Name': ['Tom', 'Jack', 'Steve', 'Ricky'], 'Age': [28, 34, 29, 42]}
df = pd.DataFrame(data, index=['rank1', 'rank2', 'rank3', 'rank4'])
print(df)
# Out:
#         Name  Age
# rank1    Tom   28
# rank2   Jack   34
# rank3  Steve   29
# rank4  Ricky   42

# %%
# -----------------------------------------------------------
# 🔹 4C. DEMO — DataFrame from a list of dicts (missing keys -> NaN)
# -----------------------------------------------------------
data = [{'a': 1, 'b': 2}, {'a': 5, 'b': 10, 'c': 20}]
df = pd.DataFrame(data)
print(df)
# Out:
#    a   b     c
# 0  1   2   NaN
# 1  5  10  20.0

# %%
# -----------------------------------------------------------
# 🔹 4D. DEMO — DataFrame from a dict of Series (union of indexes)
# -----------------------------------------------------------
d = {
    'one': pd.Series([1, 2, 3], index=['a', 'b', 'c']),
    'two': pd.Series([1, 2, 3, 4], index=['a', 'b', 'c', 'd']),
}
df = pd.DataFrame(d)
print(df)
# Out:
#    one  two
# a  1.0    1
# b  2.0    2
# c  3.0    3
# d  NaN    4

# %% [markdown]
# #### 🧪 LAB EXERCISE 4 — Build DataFrames four ways
# 1. Create `df_list` from `[['Steve', 32, 'Male'], ['Lia', 28, 'Female']]` with columns `['Name', 'Age', 'Gender']`.
# 2. Create `df_dict` from `{'Name': ['Katie', 'Vin'], 'Rating': [2.78, 3.9]}` with index `['emp1', 'emp2']`.
# 3. Create `df_records` from the list of dicts `[{'a': 1, 'b': 2}, {'a': 3, 'b': 4, 'c': 5}]` and note which cell becomes `NaN`.
# 4. Create `df_series` from a dict of two Series of your choice with **different** index labels, so at least one `NaN` appears in the result.

# %%
# 1. From list of lists
# YOUR CODE HERE
data = [['Steve', 32, 'Male'], ['Lia', 28, 'Female']]
df_list = pd.DataFrame(data , columns = ['Name', 'Age', 'Gender'])
print(df_list)

# 2. From dict of lists with custom index
# YOUR CODE HERE
data = {'Name': ['Katie', 'Vin'], 'Rating': [2.78, 3.9]}
df_dict = pd.DataFrame(data, index= ['emp1', 'emp2'])
print(df_dict)

# 3. From list of dicts
# YOUR CODE HERE
data = [{'a': 1, 'b': 2}, {'a': 3, 'b': 4, 'c': 5}]
df_records = pd.DataFrame(data)
print(df_records)

# 4. From dict of Series with differing indexes
# YOUR CODE HERE
k = {
    'one': pd.Series([1, 2, 3], index=['a', 'b', 'c']),
    'two': pd.Series([1, 2, 3, 4], index=['a', 'b', 'c', 'd']),
}
df_series = pd.DataFrame(k)
print(df_series)
# Out:
#     Name  Age  Gender
# 0  Steve   32    Male
# 1    Lia   28  Female
#        Name  Rating
# emp1  Katie    2.78
# emp2    Vin    3.90
#    a  b    c
# 0  1  2  NaN
# 1  3  4  5.0
#    one  two
# a  1.0    1
# b  2.0    2
# c  3.0    3
# d  NaN    4

# %% [markdown]
# ## 5. Column Selection, Addition & Deletion

# %%
# -----------------------------------------------------------
# 🔹 5A. DEMO — select, add, and delete columns
# -----------------------------------------------------------
d = {
    'one': pd.Series([1, 2, 3], index=['a', 'b', 'c']),
    'two': pd.Series([1, 2, 3, 4], index=['a', 'b', 'c', 'd']),
}
df = pd.DataFrame(d)

print("Select column 'one':")
print(df['one'])

print("\nAdd column 'three' from a Series:")
df['three'] = pd.Series([10, 20, 30], index=['a', 'b', 'c'])
print(df)

print("\nAdd column 'four' from existing columns:")
df['four'] = df['one'] + df['three']
print(df)

print("\nDelete column 'one' with del:")
del df['one']
print(df)

print("\nDelete column 'two' with pop:")
df.pop('two')
print(df)
# Out:
# Select column 'one':
# a    1.0
# b    2.0
# c    3.0
# d    NaN
# Name: one, dtype: float64
#
# Add column 'three' from a Series:
#    one  two  three
# a  1.0    1   10.0
# b  2.0    2   20.0
# c  3.0    3   30.0
# d  NaN    4    NaN
#
# Add column 'four' from existing columns:
#    one  two  three  four
# a  1.0    1   10.0  11.0
# b  2.0    2   20.0  22.0
# c  3.0    3   30.0  33.0
# d  NaN    4    NaN   NaN
#
# Delete column 'one' with del:
#    two  three  four
# a    1   10.0  11.0
# b    2   20.0  22.0
# c    3   30.0  33.0
# d    4    NaN   NaN
#
# Delete column 'two' with pop:
#    three  four
# a   10.0  11.0
# b   20.0  22.0
# c   30.0  33.0
# d    NaN   NaN

# %% [markdown]
# #### 🧪 LAB EXERCISE 5 — Manipulate columns
# Using `df = pd.DataFrame({'Name': ['Steve', 'Lia', 'Vin', 'Katie'], 'Age': [32, 28, 45, 38], 'Rating': [3.45, 4.6, 3.9, 2.78]})`:
# 1. Select and print the `'Rating'` column.
# 2. Add a new column `'Bonus'` equal to `Rating * 1000`.
# 3. Delete the `'Age'` column using `del`.
# 4. Remove the `'Bonus'` column using `.pop()` and print what `pop` returned.

# %%
df = pd.DataFrame({
    'Name': ['Steve', 'Lia', 'Vin', 'Katie'],
    'Age': [32, 28, 45, 38],
    'Rating': [3.45, 4.6, 3.9, 2.78],
})

# 1. Select 'Rating' column
# YOUR CODE HERE
d = pd.DataFrame(df)
print("Select column 'Rating':")
print(df['Rating'])


# 2. Add 'Bonus' column
# YOUR CODE HERE
print("\nAdd column 'Bonus' from a Series:")
d['Bonus'] = df['Rating']*1000
print(d)

# 3. Delete 'Age' column with del
# YOUR CODE HERE
print("\nDelete column 'Age' with del:")
del df['Age']
print(d)


# 4. Pop 'Bonus' column
# YOUR CODE HERE
popped = d.pop('Bonus')
print("\nDelete column 'Bonus' with pop:")
print('Popped column:')
print(popped)
print('\nRemaining DataFrame:')
print(df)
# Out:
# Select column 'Rating':
# 0    3.45
# 1    4.60
# 2    3.90
# 3    2.78
# Name: Rating, dtype: float64
#
# Add column 'Bonus' from a Series:
#     Name  Age  Rating   Bonus
# 0  Steve   32    3.45  3450.0
# 1    Lia   28    4.60  4600.0
# 2    Vin   45    3.90  3900.0
# 3  Katie   38    2.78  2780.0
#
# Delete column 'Age' with del:
#     Name  Age  Rating   Bonus
# 0  Steve   32    3.45  3450.0
# 1    Lia   28    4.60  4600.0
# 2    Vin   45    3.90  3900.0
# 3  Katie   38    2.78  2780.0
#
# Delete column 'Bonus' with pop:
# Popped column:
# 0    3450.0
# 1    4600.0
# 2    3900.0
# 3    2780.0
# Name: Bonus, dtype: float64
#
# Remaining DataFrame:
#     Name  Rating
# 0  Steve    3.45
# 1    Lia    4.60
# 2    Vin    3.90
# 3  Katie    2.78

# %% [markdown]
# ## 6. Row Selection, Addition & Deletion

# %%
# -----------------------------------------------------------
# 🔹 6A. DEMO — select rows by label (loc), by position (iloc), and by slice
# -----------------------------------------------------------
d = {
    'one': pd.Series([1, 2, 3], index=['a', 'b', 'c']),
    'two': pd.Series([1, 2, 3, 4], index=['a', 'b', 'c', 'd']),
}
df = pd.DataFrame(d)

print("Row 'b' by label (.loc):")
print(df.loc['b'])

print("\nRow at position 2 (.iloc):")
print(df.iloc[2])

print("\nSlice rows 2 to 4:")
print(df[2:4])
# Out:
# Row 'b' by label (.loc):
# one    2.0
# two    2.0
# Name: b, dtype: float64
#
# Row at position 2 (.iloc):
# one    3.0
# two    3.0
# Name: c, dtype: float64
#
# Slice rows 2 to 4:
#    one  two
# c  3.0    3
# d  NaN    4

# %%
# -----------------------------------------------------------
# 🔹 6B. DEMO — add and drop rows
# -----------------------------------------------------------
# Note: DataFrame.append() was removed in modern pandas — pd.concat() replaces it.
df1 = pd.DataFrame([[1, 2], [3, 4]], columns=['a', 'b'])
df2 = pd.DataFrame([[5, 6], [7, 8]], columns=['a', 'b'])

combined = pd.concat([df1, df2], ignore_index=False)
print('Combined (duplicate labels kept):')
print(combined)

print("\nDrop rows with label 0:")
dropped = combined.drop(0)
print(dropped)
# Out:
# Combined (duplicate labels kept):
#    a  b
# 0  1  2
# 1  3  4
# 0  5  6
# 1  7  8
#
# Drop rows with label 0:
#    a  b
# 1  3  4
# 1  7  8

# %% [markdown]
# #### 🧪 LAB EXERCISE 6 — Select, combine, and drop rows
# Using `d = {'x': pd.Series([1, 2, 3], index=['a', 'b', 'c']), 'y': pd.Series([4, 5, 6], index=['a', 'b', 'c'])}` and `df = pd.DataFrame(d)`:
# 1. Select row `'c'` using `.loc`.
# 2. Select the row at integer position `1` using `.iloc`.
# 3. Create `df_extra = pd.DataFrame({'x': [7, 8], 'y': [9, 10]}, index=['a', 'd'])` and combine it with `df` using `pd.concat`, storing the result in `combined`.
# 4. Drop every row labeled `'a'` from `combined` and print the result.

# %%
d = {
    'x': pd.Series([1, 2, 3], index=['a', 'b', 'c']),
    'y': pd.Series([4, 5, 6], index=['a', 'b', 'c']),
}
df = pd.DataFrame(d)

# 1. Select row 'c' with .loc
# YOUR CODE HERE

print("Row 'c' by label (.loc):")
print(df.loc['c'])


# 2. Select row at position 1 with .iloc
# YOUR CODE HERE
print("\nRow at position 1 (.iloc):")
print(df.iloc[1])


# 3. Combine df with df_extra using pd.concat
df_extra = pd.DataFrame({'x': [7, 8], 'y': [9, 10]}, index=['a', 'd'])
# YOUR CODE HERE
combined = pd.concat([df,df_extra], ignore_index=False)
print('Combined (duplicate labels kept):')
print(combined)

# 4. Drop rows labeled 'a'
# YOUR CODE HERE
print("\nDrop rows with label a:")
dropped = combined.drop('a')
print(dropped)
print('After dropping label a:')
print(dropped)
# Out:
# Row 'c' by label (.loc):
# x    3
# y    6
# Name: c, dtype: int64
#
# Row at position 1 (.iloc):
# x    2
# y    5
# Name: b, dtype: int64
# Combined (duplicate labels kept):
#    x   y
# a  1   4
# b  2   5
# c  3   6
# a  7   9
# d  8  10
#
# Drop rows with label a:
#    x   y
# b  2   5
# c  3   6
# d  8  10
# After dropping label a:
#    x   y
# b  2   5
# c  3   6
# d  8  10

# %% [markdown]
# **Lab complete** — check each printed output against the instructions above, and compare with the original slide examples.
